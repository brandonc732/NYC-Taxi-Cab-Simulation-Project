# %% [markdown]
# # Overview
#
# This notebook will serve as the primary place for creating the final simulation folders for the Ground Truth and 2023 simulations

# %% [markdown]
# $$ $$
#
# $$ $$
#
# # Generate 2023 simulation shift data

# %%
from utils.shift_generation_2023 import create_test_shift_information

# %%
from IPython.display import clear_output


# for loop to create test folders with shift information

base_folder = "test_sim_baselines_v5/"

test_folders = [f"test_{i}" for i in range(8)]


for test_folder in test_folders:


    print("Test_folder:", test_folder)

    test_folder = base_folder + "/" + test_folder

    
    create_test_shift_information(test_folder, make_folder=True)


    clear_output(wait=False)
# Out:
# Test_folder: test_0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 19
#      14 print("Test_folder:", test_folder)
#      16 test_folder = base_folder + "/" + test_folder
# ---> 19 create_test_shift_information(test_folder, make_folder=True)
#      22 clear_output(wait=False)
#
# File ~\Documents\CS 5834\Final Project\utils\shift_generation_2023.py:278, in create_test_shift_information(test_folder, make_folder)
#     275 if make_folder:
#     276     # check that the test folder does not exist
#     277     if test_folder.is_dir():
# --> 278         raise FileNotFoundError(f"Test folder {test_folder} exists while make_folder is True!")
#     280     os.mkdir(test_folder)
#     282 else:
#     283     # check that test folder exists
#
# FileNotFoundError: Test folder test_sim_baselines_v5\test_0 exists while make_folder is True!

# %%
create_test_shift_information

# %%
create_test_shift_information('test_v5/test_0', make_folder=True)
# Out:
# Shift start counts...
# Shift durations...
# Shift start locations...
# driver counts...
# Applying 2013 to 2023 scaling
# 100%|█████████████████████████████████████████████████████████████████████████| 9073/9073 [00:26<00:00, 342.18it/s]
# Creating dataframe:...
# done

# %% [markdown]
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# $$ $$
#
# # Generate 2013 simulation shift data

# %%
from utils.shift_generation_2013 import create_ground_truth_test_shift_information

# %%
from IPython.display import clear_output


# for loop to create test folders with shift information

base_folder = "gt_test_v4"

test_folders = [f"test_{i}" for i in range(8)]

for test_folder in test_folders:


    print("Test_folder:", test_folder)

    test_folder = base_folder + "/" + test_folder

    
    create_ground_truth_test_shift_information(test_folder, make_folder=True)


    clear_output(wait=False)

# %%
import numpy as np

# %%
dists = np.load('test_sim_baselines_v5/extra/total_distances_array.npy')
